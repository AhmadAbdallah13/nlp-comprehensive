# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, CategoriesOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

#return catagories
response = natural_language_understanding.analyze(
    url='https://www.dailymail.co.uk/home/index.html',
    features=Features(categories=CategoriesOptions(limit=5))).get_result()
jsonRespo=json.dumps(response, indent=2)
print(jsonRespo)
# Out:
# {
#   "usage": {
#     "text_units": 5,
#     "text_characters": 50000,
#     "features": 1
#   },
#   "retrieved_url": "https://www.dailymail.co.uk/home/index.html",
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.746297,
#       "label": "/society/dating"
#     },
#     {
#       "score": 0.740389,
#       "label": "/art and entertainment/shows and events"
#     },
#     {
#       "score": 0.718894,
#       "label": "/family and parenting/babies and toddlers/baby clothes"
#     },
#     {
#       "score": 0.708828,
#       "label": "/family and parenting/parenting teens"
#     },
#     {
#       "score": 0.692937,
#       "label": "/sports/go kart"
#     }
#   ],
#   "warnings": [
#     "Text content exceeds 50000 character limit. Only first 50000 characters processed..."
#   ]
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, ConceptsOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

# return concepts
# when i put ar instead of es (espaniol) gives error
response = natural_language_understanding.analyze(
    url='https://www.kooora.com/',
    features=Features(concepts=ConceptsOptions(limit=3)),
        language='es'
        ).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 69,
#     "features": 1
#   },
#   "retrieved_url": "https://www.kooora.com/",
#   "language": "es",
#   "concepts": []
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EmotionOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')
#return emotions
response = natural_language_understanding.analyze(
    html="<html><head><title>Fruits</title></head><body><h1>Apples and Oranges</h1><p>I love apples! I don't like oranges.</p></body></html>",
    features=Features(emotion=EmotionOptions(targets=['apples','oranges'],document=False))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 37,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "targets": [
#       {
#         "text": "apples",
#         "emotion": {
#           "sadness": 0.028574,
#           "joy": 0.859042,
#           "fear": 0.02752,
#           "disgust": 0.017519,
#           "anger": 0.012855
#         }
#       },
#       {
#         "text": "oranges",
#         "emotion": {
#           "sadness": 0.514253,
#           "joy": 0.078317,
#           "fear": 0.074223,
#           "disgust": 0.058103,
#           "anger": 0.126859
#         }
#       }
#     ]
#   }
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

#return entities
response = natural_language_understanding.analyze(
#     language="ar",
    url='www.Koora.com',
    features=Features(entities=EntitiesOptions(sentiment=True,limit=1))).get_result()

print(json.dumps(response, indent=2))

# import json
# from ibm_watson import NaturalLanguageUnderstandingV1
# from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
# from ibm_watson.natural_language_understanding_v1  import Features, EntitiesOptions, KeywordsOptions

# authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
# natural_language_understanding = NaturalLanguageUnderstandingV1(
#     version='2019-07-12',
#     authenticator=authenticator
# )

# natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

# response = natural_language_understanding.analyze(
#     text='IBM is an American multinational technology company '
#     'headquartered in Armonk, New York, United States, '
#     'with operations in over 170 countries.',
#     features=Features(
#         entities=EntitiesOptions(emotion=True, sentiment=True, limit=2),
#         keywords=KeywordsOptions(emotion=True, sentiment=True,
#                                  limit=2),
#         language='ar')).get_result()

# print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 14066,
#     "features": 1
#   },
#   "retrieved_url": "http://www.koora.com/",
#   "language": "fr",
#   "entities": [
#     {
#       "type": "Ordinal",
#       "text": "28\u00e8me",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.949105,
#       "count": 3
#     }
#   ]
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, KeywordsOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

#Returns important keywords 
response = natural_language_understanding.analyze(
    url='www.ibm.com',
    features=Features(keywords=KeywordsOptions(sentiment=True,emotion=True,limit=2))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 717,
#     "features": 1
#   },
#   "retrieved_url": "https://www.ibm.com/uk-en",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "Virtual Security Summit",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.757291,
#       "emotion": {
#         "sadness": 0.120371,
#         "joy": 0.473437,
#         "fear": 0.099526,
#         "disgust": 0.012907,
#         "anger": 0.058682
#       },
#       "count": 1
#     },
#     {
#       "text": "latest IBM stories",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.710728,
#       "emotion": {
#         "sadness": 0.050359,
#         "joy": 0.556432,
#         "fear": 0.078952,
#         "disgust": 0.014179,
#         "anger": 0.045997
#       },
#       "count": 1
#     }
#   ]
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, MetadataOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

#Returns information from the document, including author name, title, RSS/ATOM feeds, prominent page image, 
#and publication date. Supports URL and HTML input types only.
response = natural_language_understanding.analyze(
    url='www.ibm.com',
    features=Features(metadata=MetadataOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 717,
#     "features": 1
#   },
#   "retrieved_url": "https://www.ibm.com/uk-en",
#   "metadata": {
#     "title": "IBM - United Kingdom",
#     "publication_date": "",
#     "image": "https://1.www.s81c.com/common/images/ibm-leadspace-1200x627.jpg",
#     "feeds": [],
#     "authors": []
#   },
#   "language": "en"
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, RelationsOptions, ConceptsOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

# Recognizes when two entities are related and identifies the type of relation
response = natural_language_understanding.analyze(
    text='Leonardo DiCaprio won Best Actor in a Leading Role for his performance.',
    features=Features(concepts=ConceptsOptions(),relations=RelationsOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 71,
#     "features": 2
#   },
#   "relations": [
#     {
#       "type": "awardedTo",
#       "sentence": "Leonardo DiCaprio won Best Actor in a Leading Role for his performance.",
#       "score": 0.680715,
#       "arguments": [
#         {
#           "text": "Best Actor",
#           "location": [
#             22,
#             32
#           ],
#           "entities": [
#             {
#               "type": "EntertainmentAward",
#               "text": "Best Actor"
#             }
#           ]
#         },
#         {
#           "text": "Leonardo DiCaprio",
#           "location": [
#             0,
#             17
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Leonardo DiCaprio"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en",
#   "concepts": [
#     {
#       "text": "Leonardo DiCaprio",
# ...

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, SemanticRolesOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

#Parses sentences into subject, action, and object form.
response = natural_language_understanding.analyze(
    text='IBM has one of the largest workforces in the world',
    features=Features(semantic_roles=SemanticRolesOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 50,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "IBM"
#       },
#       "sentence": "IBM has one of the largest workforces in the world",
#       "object": {
#         "text": "one of the largest workforces in the world"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "have"
#       }
#     }
#   ],
#   "language": "en"
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, SentimentOptions

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

response = natural_language_understanding.analyze(
    url='www.wsj.com/news/markets',
    features=Features(sentiment=SentimentOptions(targets=['stocks']))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 210,
#     "features": 1
#   },
#   "sentiment": {
#     "targets": [
#       {
#         "text": "stocks",
#         "score": 0.831769,
#         "label": "positive"
#       }
#     ],
#     "document": {
#       "score": 0.799017,
#       "label": "positive"
#     }
#   },
#   "retrieved_url": "https://www.wsj.com/news/markets",
#   "language": "en"
# }

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, SyntaxOptions, SyntaxOptionsTokens

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

#Returns information about the tokens and sentences in the input text. 
#At least one of syntax.tokens or syntax.sentences must be specified.
response = natural_language_understanding.analyze(
    text='With great power comes great responsibility',
    features=Features(
      syntax=SyntaxOptions(
        sentences=True,
        tokens=SyntaxOptionsTokens(
          lemma=True,
          part_of_speech=True,
        )))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 43,
#     "features": 0
#   },
#   "syntax": {
#     "tokens": [
#       {
#         "text": "With",
#         "part_of_speech": "ADP",
#         "location": [
#           0,
#           4
#         ],
#         "lemma": "with"
#       },
#       {
#         "text": "great",
#         "part_of_speech": "ADJ",
#         "location": [
#           5,
#           10
#         ],
#         "lemma": "great"
#       },
#       {
#         "text": "power",
#         "part_of_speech": "NOUN",
#         "location": [
#           11,
#           16
#         ],
#         "lemma": "power"
#       },
#       {
#         "text": "comes",
#         "part_of_speech": "VERB",
#         "location": [
#           17,
#           22
#         ],
#         "lemma": "come"
#       },
#       {
#         "text": "great",
#         "part_of_speech": "ADJ",
#         "location": [
#           23,
#           28
#         ],
# ...

# %%
# Error handling.

# from ibm_watson import ApiException
# try:
#     # Invoke a Natural Language Understanding method
# except ApiException as ex:
#     print "Method failed with status code " + str(ex.code) + ": " + ex.message


# respone info

# natural_language_understanding.set_detailed_response(True)
# response = natural_language_understanding.methodName(parameters)
# # Access response from methodName
# print(json.dumps(response.get_result(), indent=2))
# # Access information in response headers
# print(response.get_headers())
# # Access HTTP response status
# print(response.get_status_code())

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('wesAWF34Qi8uqG5gMDJCWMiPo07KjYRGdNtJWNh37877')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

#Lists Watson Knowledge Studio custom entities
#and relations models that are deployed to your Natural Language Understanding service.
natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/a0e17757-dd30-4b66-9349-76c15d42a24a')

response = natural_language_understanding.list_models().get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "models": []
# }
